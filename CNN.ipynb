# %%
#---2D CNN model
import keras
from livelossplot import PlotLossesKeras
from keras.optimizers import SGD
from keras.layers import Conv2D, BatchNormalization, Activation, SpatialDropout2D, MaxPooling2D,AveragePooling2D, GlobalAveragePooling2D, Dense, Dropout
from keras.utils import multi_gpu_model
from keras.callbacks import ReduceLROnPlateau, ModelCheckpoint

model = keras.Sequential()
model.add(Conv2D(32, (7,7), kernel_initializer='glorot_uniform',padding='same',kernel_regularizer=keras.regularizers.l2(0.001),input_shape=(160, 160, 1)))
model.add(Conv2D(32, (7,7), kernel_initializer='glorot_uniform',padding='same',kernel_regularizer=keras.regularizers.l2(0.001)))
model.add(BatchNormalization())
model.add(Activation("relu"))
model.add(SpatialDropout2D(0.3))
model.add(MaxPooling2D(pool_size=(2, 2), strides=(2, 2)))


model.add(Conv2D(64, (3,3), kernel_initializer='glorot_uniform',padding='same',kernel_regularizer=keras.regularizers.l2(0.001)))
model.add(Conv2D(64, (3,3), kernel_initializer='glorot_uniform',padding='same',kernel_regularizer=keras.regularizers.l2(0.001)))
model.add(BatchNormalization())
model.add(Activation("relu"))
model.add(SpatialDropout2D(0.3))
model.add(MaxPooling2D(pool_size=(2, 2), strides=(2, 2)))


model.add(Conv2D(128, (3,3), kernel_initializer='glorot_uniform',padding='same',kernel_regularizer=keras.regularizers.l2(0.001)))
model.add(Conv2D(128, (3,3), kernel_initializer='glorot_uniform',padding='same',kernel_regularizer=keras.regularizers.l2(0.001)))
model.add(BatchNormalization())
model.add(Activation("relu"))
model.add(SpatialDropout2D(0.3))
model.add(MaxPooling2D(pool_size=(2, 2), strides=(2, 2)))

model.add(Conv2D(256, (3,3), kernel_initializer='glorot_uniform',padding='same',kernel_regularizer=keras.regularizers.l2(0.001)))
model.add(Conv2D(256, (3,3), kernel_initializer='glorot_uniform',padding='same',kernel_regularizer=keras.regularizers.l2(0.001)))
model.add(BatchNormalization())
model.add(Activation("relu"))
model.add(SpatialDropout2D(0.3))
model.add(AveragePooling2D(pool_size=(2, 2), strides=(2, 2)))

model.add(Conv2D(512, (3,3), kernel_initializer='glorot_uniform',padding='same',kernel_regularizer=keras.regularizers.l2(0.001)))
model.add(Conv2D(512, (3,3), kernel_initializer='glorot_uniform',padding='same',kernel_regularizer=keras.regularizers.l2(0.001)))
model.add(BatchNormalization())
model.add(Activation("relu"))
model.add(SpatialDropout2D(0.3))
model.add(AveragePooling2D(pool_size=(2, 2), strides=(2, 2)))
model.add(GlobalAveragePooling2D())

model.add(Dense(512))
model.add(BatchNormalization())
model.add(Activation("relu"))
model.add(Dropout(0.3))

model.add(Dense(256))
model.add(BatchNormalization())
model.add(Activation("relu"))
model.add(Dropout(0.3))

model.add(Dense(128))
model.add(BatchNormalization())
model.add(Activation("relu"))
model.add(Dropout(0.3))

model.add(Dense(64))
model.add(BatchNormalization())
model.add(Activation("relu"))
model.add(Dropout(0.3))

model.add(Dense(1))
model.add(BatchNormalization())
model.add(Activation("sigmoid"))
model.summary()
model = multi_gpu_model(model,gpus = None, cpu_merge=True, cpu_relocation=False)
model.compile(optimizer=SGD(lr = 0.01,decay=1e-6, momentum=0.9, nesterov=True), loss='binary_crossentropy',metrics=['accuracy'])

filepath=r"XX.hdf5"
checkpoint = ModelCheckpoint(filepath, monitor='val_loss', verbose=1, save_best_only=True, mode='min')
callbacks_list = [checkpoint,PlotLossesKeras()]
history = model.fit(X_train, Y_train, validation_data=(X_test,Y_test),callbacks=callbacks_list, epochs = 200,batch_size=64,shuffle=False)

# %%
#---3D CNN model
import keras
from livelossplot import PlotLossesKeras
from keras.optimizers import SGD
from keras.layers import Conv3D, BatchNormalization, Activation,SpatialDropout3D, MaxPooling3D, AveragePooling3D, GlobalAveragePooling3D, Dense, Dropout
from keras.utils import multi_gpu_model
from keras.callbacks import LearningRateScheduler, ModelCheckpoint

model = keras.Sequential()
model.add(Conv3D(32, (1,7,7), kernel_initializer='glorot_uniform',padding='same',kernel_regularizer=keras.regularizers.l2(0.001),input_shape=(10, 160, 160, 1)))
model.add(Conv3D(32, (1,7,7), kernel_initializer='glorot_uniform',padding='same',kernel_regularizer=keras.regularizers.l2(0.001)))
model.add(BatchNormalization())
model.add(Activation("relu"))
model.add(SpatialDropout3D(0.3))
model.add(MaxPooling3D(pool_size=(1, 2, 2), strides=(1, 2, 2)))


model.add(Conv3D(64, (1,3,3), kernel_initializer='glorot_uniform',padding='same',kernel_regularizer=keras.regularizers.l2(0.001)))
model.add(Conv3D(64, (1,3,3), kernel_initializer='glorot_uniform',padding='same',kernel_regularizer=keras.regularizers.l2(0.001)))
model.add(BatchNormalization())
model.add(Activation("relu"))
model.add(SpatialDropout3D(0.3))
model.add(MaxPooling3D(pool_size=(1, 2, 2), strides=(1, 2, 2)))


model.add(Conv3D(128, (1,3,3), kernel_initializer='glorot_uniform',padding='same',kernel_regularizer=keras.regularizers.l2(0.001)))
model.add(Conv3D(128, (1,3,3), kernel_initializer='glorot_uniform',padding='same',kernel_regularizer=keras.regularizers.l2(0.001)))
model.add(BatchNormalization())
model.add(Activation("relu"))
model.add(SpatialDropout3D(0.3))
model.add(MaxPooling3D(pool_size=(1, 2, 2), strides=(1, 2, 2)))

model.add(Conv3D(256, (1,3,3), kernel_initializer='glorot_uniform',padding='same',kernel_regularizer=keras.regularizers.l2(0.001)))
model.add(Conv3D(256, (1,3,3), kernel_initializer='glorot_uniform',padding='same',kernel_regularizer=keras.regularizers.l2(0.001)))
model.add(BatchNormalization())
model.add(Activation("relu"))
model.add(SpatialDropout3D(0.3))
model.add(AveragePooling3D(pool_size=(1, 2, 2), strides=(1, 2, 2)))


model.add(Conv3D(512, (3,3,3), kernel_initializer='glorot_uniform',padding='same',kernel_regularizer=keras.regularizers.l2(0.001)))
model.add(Conv3D(512, (3,3,3), kernel_initializer='glorot_uniform',padding='same',kernel_regularizer=keras.regularizers.l2(0.001)))
model.add(BatchNormalization())
model.add(Activation("relu"))
model.add(SpatialDropout3D(0.3))
model.add(AveragePooling3D(pool_size=(2, 2, 2), strides=(2, 2, 2)))

model.add(GlobalAveragePooling3D())

model.add(Dense(512))
model.add(BatchNormalization())
model.add(Activation("relu"))
model.add(Dropout(0.3))

model.add(Dense(256))
model.add(BatchNormalization())
model.add(Activation("relu"))
model.add(Dropout(0.3))

model.add(Dense(128))
model.add(BatchNormalization())
model.add(Activation("relu"))
model.add(Dropout(0.3))

model.add(Dense(64))
model.add(BatchNormalization())
model.add(Activation("relu"))
model.add(Dropout(0.3))

model.add(Dense(1))
model.add(Activation("sigmoid"))
model.summary()
model = multi_gpu_model(model,gpus = None, cpu_merge=True, cpu_relocation=False)
model.compile(optimizer=SGD(lr = 0.01,decay=1e-6, momentum=0.9, nesterov=False), loss='binary_crossentropy',metrics=['accuracy'])

filepath=r"XX.hdf5"
checkpoint = ModelCheckpoint(filepath, monitor='val_loss', verbose=1, save_best_only=True, mode='min')
callbacks_list = [checkpoint,PlotLossesKeras()]
history = model.fit(X_train, Y_train, validation_data=(X_test,Y_test),callbacks=callbacks_list, epochs = 200,batch_size=32,shuffle=False)
